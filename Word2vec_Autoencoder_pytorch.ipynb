# %% [markdown]
# <a href="https://colab.research.google.com/github/darkwingpatil/Ml_hackethons/blob/main/Word2vec_Autoencoder_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint

# %% [markdown]
# ### Learning Objectives

# %% [markdown]
# At the end of the experiment, you will be able to :
#
# * understand how to deal with the text preprocessing
# * create effective semantic representations of variable sized text

# %%
#@title Experiment Explanation Video
from IPython.display import HTML

HTML("""<video width="850" height="480" controls>
  <source src="https://cdn.iiith.talentsprint.com/aiml/Experiment_related_data/Walkthrough/Autoencoders_Word2vec_Walkthrough.mp4" type="video/mp4">
</video>
""")

# %% [markdown]
# ### Dataset
#
# In this experiment we use the 20 newsgroup dataset

# %% [markdown]
# ### Description
#
# This dataset is a collection of approximately 20,000 newsgroup documents, partitioned nearly evenly across 20 different newsgroups. That is there are approximately one thousand documents taken from each of the following newsgroups:
#
#     alt.athesim
#     comp.graphics
#     comp.os.ms-windows.misc
#     comp.sys.ibm.pc.hardware
#     comp.sys.mac.hardware
#     comp.windows.x
#     misc.forsale
#     rec.autos
#     rec.motorcycles
#     rec.sport.baseball
#     rec.sport.hockey
#     sci.crypt
#     sci.electronics
#     sci.med
#     sci.space
#     soc.religion.christian
#     talk.politics.guns
#     talk.politics.mideast
#     talk.politics.misc
#     talk.religion.misc
#
# The dataset consists **Usenet** posts--essentially an email sent by someone to that newsgroup. They typically contain quotes from previous posts as well as cross posts; that is a few posts that may be sent to more than one newsgroup.
#
# Each newsgroup is stored in a subdirectory, with each post stored as a separate file.
#
# Data source to this experiment: http://archive.ics.uci.edu/ml/datasets/Twenty+Newsgroups

# %% [markdown]
# ### Domain Information

# %% [markdown]
# A newsgroup, despite the name, has nothing to do with news. It is what we would call today a mailing list or a discussion forum. *Usenet* is a distributed discussion system designed and developed in 1979 and deployed in 1980.
#
# Members joined newsgroups of interest to them and made *posts* to them. Posts are very similar to email -- in later years, newsgroups became mailing lists and people posted via email.

# %% [markdown]
# ### AI/ML Technique

# %% [markdown]
# ### Autoencoder
#
# An autoencoder is a feedforward, non-recurrent neural network which is similar to a multilayer perceptron (MLP) – having an input layer, an output layer and one or more hidden layers connecting them. However, in an autoencoder, the output layer has the same number of nodes as the input layer and reconstructs its own inputs (instead of predicting the target value Y given inputs X).
#
#
# An autoencoder is made up of two components- the encoder and the decoder network. The task of the encoder is to generate a lower-dimensional embedding Z, which is referred to as latent vector, or latent representation. After that, we have the decoder stage in which Z is reconstructed to X' prime, which is the same as X (input).
#
#
# ![alt text](https://cdn.talentsprint.com/aiml/Experiment_related_data/IMAGES/6.png)

# %% [markdown]
# ### Setup Steps:

# %%
#@title Please enter your registration id to start: { run: "auto", display-mode: "form" }
Id = "2304145" #@param {type:"string"}

# %%
#@title Please enter your password (normally your phone number) to continue: { run: "auto", display-mode: "form" }
password = "7892449987" #@param {type:"string"}

# %%
#@title Run this cell to complete the setup for this Notebook
from IPython import get_ipython
import re
ipython = get_ipython()

notebook= "U4W18_62_Autoencoder_Word2vec_text_A" #name of the notebook

def setup():
#  ipython.magic("sx pip3 install torch")
    from IPython.display import HTML, display
    ipython.magic("sx pip3 install torch")
    ipython.magic("sx pip install torchvision")
    ipython.magic("sx pip install gensim")
    ipython.magic("sx wget https://cdn.talentsprint.com/aiml/Experiment_related_data/week9/Exp2/AIML_DS_NEWSGROUPS_PICKELFILE.pkl.zip")
    ipython.magic("sx unzip AIML_DS_NEWSGROUPS_PICKELFILE.pkl.zip")
    ipython.magic("sx wget https://cdn.talentsprint.com/aiml/Experiment_related_data/week9/Exp2/AIML_DS_GOOGLENEWS-VECTORS-NEGATIVE-300_STD.bin")
    display(HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id)))
    print("Setup completed successfully")
    return

def submit_notebook():
    ipython.magic("notebook -e "+ notebook + ".ipynb")

    import requests, json, base64, datetime

    url = "https://dashboard.talentsprint.com/xp/app/save_notebook_attempts"
    if not submission_id:
      data = {"id" : getId(), "notebook" : notebook, "mobile" : getPassword()}
      r = requests.post(url, data = data)
      r = json.loads(r.text)

      if r["status"] == "Success":
          return r["record_id"]
      elif "err" in r:
        print(r["err"])
        return None
      else:
        print ("Something is wrong, the notebook will not be submitted for grading")
        return None

    elif getAnswer() and getComplexity() and getAdditional() and getConcepts() and getWalkthrough() and getComments() and getMentorSupport():
      f = open(notebook + ".ipynb", "rb")
      file_hash = base64.b64encode(f.read())

      data = {"complexity" : Complexity, "additional" :Additional,
              "concepts" : Concepts, "record_id" : submission_id,
              "answer" : Answer, "id" : Id, "file_hash" : file_hash,
              "notebook" : notebook, "feedback_walkthrough":Walkthrough ,
              "feedback_experiments_input" : Comments,
              "feedback_inclass_mentor": Mentor_support}

      r = requests.post(url, data = data)
      r = json.loads(r.text)
      if "err" in r:
        print(r["err"])
        return None
      else:
        print("Your submission is successful.")
        print("Ref Id:", submission_id)
        print("Date of submission: ", r["date"])
        print("Time of submission: ", r["time"])
        print("View your submissions: https://aiml-iiith.talentsprint.com/notebook_submissions")
        #print("For any queries/discrepancies, please connect with mentors through the chat icon in LMS dashboard.")
        return submission_id
    else: submission_id


def getAdditional():
  try:
    if not Additional:
      raise NameError
    else:
      return Additional
  except NameError:
    print ("Please answer Additional Question")
    return None

def getComplexity():
  try:
    if not Complexity:
      raise NameError
    else:
      return Complexity
  except NameError:
    print ("Please answer Complexity Question")
    return None

def getConcepts():
  try:
    if not Concepts:
      raise NameError
    else:
      return Concepts
  except NameError:
    print ("Please answer Concepts Question")
    return None


def getWalkthrough():
  try:
    if not Walkthrough:
      raise NameError
    else:
      return Walkthrough
  except NameError:
    print ("Please answer Walkthrough Question")
    return None

def getComments():
  try:
    if not Comments:
      raise NameError
    else:
      return Comments
  except NameError:
    print ("Please answer Comments Question")
    return None


def getMentorSupport():
  try:
    if not Mentor_support:
      raise NameError
    else:
      return Mentor_support
  except NameError:
    print ("Please answer Mentor support Question")
    return None

def getAnswer():
  try:
    if not Answer:
      raise NameError
    else:
      return Answer
  except NameError:
    print ("Please answer Question")
    return None


def getId():
  try:
    return Id if Id else None
  except NameError:
    return None

def getPassword():
  try:
    return password if password else None
  except NameError:
    return None

submission_id = None
### Setup
if getPassword() and getId():
  submission_id = submit_notebook()
  if submission_id:
    setup()
else:
  print ("Please complete Id and Password cells before running setup")
# Out:
# <script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId=2304145&recordId=7780"></script>
# Setup completed successfully

# %% [markdown]
# ### Importing required packages

# %%
# Importing pytorch packages
import torch
from torch import nn
import torch.optim as optim

import torchvision
from torchvision import datasets, transforms

import numpy as np
import gensim

# Matplotlib is used for ploting graphs
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading the dataset

# %%
import pickle
dataset = pickle.load(open("AIML_DS_NEWSGROUPS_PICKELFILE.pkl",'rb'))
print(dataset.keys())
# Out:
# dict_keys(['talk.politics.mideast', 'rec.autos', 'comp.sys.mac.hardware', 'alt.atheism', 'rec.sport.baseball', 'comp.os.ms-windows.misc', 'rec.sport.hockey', 'sci.crypt', 'sci.med', 'talk.politics.misc', 'rec.motorcycles', 'comp.windows.x', 'comp.graphics', 'comp.sys.ibm.pc.hardware', 'sci.electronics', 'talk.politics.guns', 'sci.space', 'soc.religion.christian', 'misc.forsale', 'talk.religion.misc'])

# %% [markdown]
# ### Dividing the dataset into train and test
#
# We will use 950 samples from each class in the training set, and the remaining 50 (Are you sure?)  in the test set.

# %%
train_set = {}
test_set = {}


# Clean dataset for text encoding issues :- Very useful when dealing with non-unicode characters
for key in dataset:
    # Decode the text in pickle_dataset using utf-8 decoding. Try reading about the necessity for this action.
    # Also convert to lower case
    dataset[key] = [[i.decode('utf-8', errors='replace').lower() for i in f] for f in dataset[key]]
    # YOUR CODE HERE

# Break dataset into 95-5 split for training and testing
n_train = 0
n_test = 0
for k in dataset:
    split = int(0.95*len(dataset[k]))
    # print(len(formed_dataset[k]))
    train_set[k] = dataset[k][0:split]
    test_set[k] = dataset[k][split:-1]
    n_train += len(train_set[k])
    n_test += len(test_set[k])

# %%
print(len(dataset))
print(len(train_set.get('talk.politics.misc')))
print(len(test_set.get('talk.politics.misc')))
# print(len(test_set['alt.athesim']))

print(n_train)
print(n_test)
# Out:
# 20
# 736
# 38
# 17878
# 930

# %%
for label, class_name in enumerate(dataset):
    print(label, class_name)

    print(len(formed_dataset[class_name]),len(formed_dataset[class_name][34]))

    break
# Out:
# 0 talk.politics.mideast
# 940 17

# %% [markdown]
# ### Calculating the frequency of the words

# %% [markdown]
# As you might have realized, machine learning algorithms need good feature representations of different inputs. Concretely, we would like to represent each news article 𝐷 in terms of a feature vector 𝑉, which can be used for classification. Feature vector 𝑉 is made up of the number of occurrences of each word in the vocabulary. Let us count the number of occurrences of every word in the news documents in the training set.

# %%
import collections
import re
import operator
frequency = collections.defaultdict(int)

for key in train_set:
    for f in train_set[key]:

        # Find all words which consist only of capital and lowercase characters and are between length of 2-9.
        # We ignore all special characters such as !.$ and words containing numbers
        words = re.findall(r'\b[A-Za-z]{2,9}\b',' '.join(f))
        # YOUR CODE HERE

        for word in words:
            # YOUR CODE HERE: Use the defaultdict called "frequency" and populate into it the frequency (the count of) each word in 'words'
            frequency[word] += 1

sorted_words = sorted(frequency.items(), key=operator.itemgetter(1), reverse=True)

print(frequency)
# Out:
# defaultdict(<class 'int'>, {'from': 35358, 'hm': 136, 'cs': 3744, 'brown': 398, 'edu': 27853, 'harry': 161, 'mamaysky': 31, 'subject': 19335, 'heil': 15, 'hernlem': 99, 'in': 76777, 'article': 10903, 'ncsu': 249, 'chess': 65, 'brad': 317, 'writes': 12693, 'lebanese': 160, 'forces': 328, 'detonated': 8, 'bomb': 143, 'under': 2387, 'an': 15506, 'israeli': 858, 'patrol': 30, 'territory': 141, 'two': 4718, 'days': 1191, 'ago': 1190, 'three': 1568, 'soldiers': 394, 'were': 8823, 'killed': 869, 'and': 90621, 'wounded': 104, 'backed': 96, 'civilians': 230, 'by': 17162, 'several': 1472, 'villages': 246, 'the': 226860, 'justifies': 34, 'its': 3784, 'lebanon': 159, 'claiming': 205, 'that': 62088, 'it': 52288, 'is': 66651, 'necessary': 617, 'to': 114567, 'prevent': 406, 'such': 4289, 'of': 102034, 'brave': 50, 'men': 1015, 'with': 27234, 'every': 2119, 'son': 551, 'you': 42430, 'place': 1577, 'grave': 66, 'are': 28355, 'moral': 665, 'israel': 1476, 'drawing': 255, 'attention': 288, 'policy': 664, 'reckless': 23, 'disregard': 60, 'for': 43546, 'civilian': 148, 'life': 1863, 'very': 4878, 'nice': 876, 'people': 8950, 'murdered': 121, 'bradly': 2, 'overjoyed': 3, 'when': 8938, 'hear': 775, 'about': 13013, 'deaths': 250, 'middle': 427, 'east': 615, 'be': 29347, 'jewish': 990, 'or': 23004, 'arab': 606, 'feel': 1128, 'sadness': 5, 'only': 7803, 'hope': 1156, 'soon': 631, 'this': 31001, 'all': 14538, 'stops': 90, 'my': 15152, 'view': 885, 'point': 2930, 'not': 28645, 'like': 9214, 'disgust': 15, 'me': 10599, 'waldo': 21, 'cybernet': 26, 'cse': 72, 'fau': 27, 'todd': 183, 'dicker': 6, 're': 16738, 'expansion': 247, 'ii': 733, 'virginia': 660, 'andi': 98, 'beyer': 97, 'first': 4585, 'never': 2836, 'said': 3825, 'holocaust': 205, 'before': 2971, 'ignorant': 147, 'know': 8237, 'more': 9215, 'nazi': 312, 'germany': 452, 'than': 7428, 'most': 4379, 'maybe': 1636, 'including': 1048, 'uh': 295, 'oh': 919, 'sign': 288, 'argument': 851, 'without': 2614, 'merit': 53, 'stating': 92, 'one': 13858, 'area': 1027, 'if': 21454, 'something': 3446, 'show': 1187, 'don': 9521, 'shut': 190, 'up': 8467, 'simple': 827, 'as': 24727, 'think': 7205, 'suffering': 181, 'some': 10438, 'jews': 1257, 'during': 1386, 'wwii': 95, 'crimes': 199, 'commited': 39, 'any': 10969, 'attempt': 467, 'call': 1729, 'civil': 412, 'myself': 784, 'anti': 741, 'semetic': 9, 'suffered': 146, 'just': 8923, 'our': 4050, 'beloved': 51, 'who': 10350, 'perished': 24, 'tortured': 59, 'we': 13995, 'second': 1821, 'name': 1956, 'calling': 371, 'was': 21681, 'directed': 123, 'against': 2159, 'general': 1570, 'your': 11694, 'dropping': 59, 'fancy': 103, 'sounding': 57, 'political': 725, 'term': 660, 'yet': 1608, 'another': 2623, 'cite': 109, 'order': 1614, 'obfuscate': 32, 'glaring': 23, 'go': 3896, 'back': 3253, 'minors': 62, 'junior': 48, 'gannon': 10, 'newcastle': 43, 'ac': 1924, 'uk': 2101, 'space': 2439, 'cadet': 2, 'exact': 270, 'million': 638, 'readers': 245, 'serdar': 307, 'argic': 300, 'andrew': 1138, 'varvel': 3, 'merciful': 22, 'bountiful': 3, 'divine': 178, 'knowing': 313, 'footnoted': 3, 'wisdom': 207, 'omitted': 50, 'solemn': 7, 'tribute': 13, 'where': 4141, 'can': 17717, 'join': 246, 'fan': 524, 'club': 257, 'do': 13621, 'get': 7881, 'shirt': 31, 'friendly': 125, 'alien': 77, 'hasn': 271, 'been': 7204, 'same': 3768, 'since': 3308, 'david': 2561, 'koresh': 701, 'died': 444, 'ah': 434, 'mon': 267, 'give': 2163, 'guy': 821, 'see': 4885, 'what': 15668, 'comes': 1036, 'leo': 126, 'wasn': 703, 'honest': 203, 'email': 1629, 'him': 3337, 'he': 13093, 'made': 2555, 'shaig': 31, 'com': 16636, 'shai': 56, 'guday': 46, 'basil': 36, 'opinions': 1302, 'water': 639, 'on': 31885, 'brain': 319, 'thunder': 86, 'mcrcim': 114, 'mcgill': 265, 'hasan': 78, 'nysernet': 54, 'org': 1918, 'astein': 36, 'alan': 364, 'stein': 107, 'guess': 1044, 'finally': 542, 'revealed': 144, 'source': 1339, 'his': 7124, 'claim': 1042, 'diverted': 17, 'mr': 1665, 'head': 854, 'rivers': 23, 'fact': 2238, 'went': 1101, 'into': 4861,  ...

# %% [markdown]
# ### Preprocessing the data

# %% [markdown]
# Now we got some rough ideas about kind of words that appear frequently, and those that occur rarely, and we can observe that different words appear with different frequencies. The most common words appear in almost all documents. Hence, for a classification task, having information about those words' frequencies does not matter much since they appear frequently in every type of document. To get a good feature representation, we eliminate them since they do not add too much value. Additionally, notice how the least frequent words appear so rarely that they might not be useful either.
#
#
# Let us pre-process our news articles now to remove the most frequent and least frequent words by thresholding their counts:

# %%
valid_words = collections.defaultdict(int)

print('Number of words before preprocessing:', len(sorted_words))

# Ignore the 25 most frequent words, and the words which appear less than 100 times
ignore_most_frequent = 25
freq_thresh = 100
feature_number = 0
for word, word_frequency in sorted_words[ignore_most_frequent:]:
    if word_frequency > freq_thresh:
        valid_words[word] = feature_number
        feature_number += 1

print('Number of words after preprocessing:', len(valid_words))

word_vector_size = len(valid_words)
# Out:
# Number of words before preprocessing: 83104
# Number of words after preprocessing: 4165

# %%
print(valid_words)
# Out:
# defaultdict(<class 'int'>, {'they': 0, 'subject': 1, 'can': 2, 'by': 3, 're': 4, 'at': 5, 'com': 6, 'what': 7, 'an': 8, 'there': 9, 'my': 10, 'all': 11, 'would': 12, 'we': 13, 'one': 14, 'will': 15, 'do': 16, 'he': 17, 'about': 18, 'writes': 19, 'so': 20, 'no': 21, 'your': 22, 'has': 23, 'any': 24, 'article': 25, 'me': 26, 'some': 27, 'who': 28, 'out': 29, 'which': 30, 'don': 31, 'more': 32, 'like': 33, 'people': 34, 'when': 35, 'just': 36, 'were': 37, 'their': 38, 'up': 39, 'know': 40, 'how': 41, 'other': 42, 'get': 43, 'only': 44, 'them': 45, 'had': 46, 'than': 47, 'think': 48, 'been': 49, 'his': 50, 'also': 51, 'does': 52, 'use': 53, 'time': 54, 'then': 55, 'these': 56, 'new': 57, 'good': 58, 'should': 59, 'could': 60, 'well': 61, 'am': 62, 'because': 63, 'may': 64, 'now': 65, 'even': 66, 'us': 67, 'why': 68, 'see': 69, 'very': 70, 'into': 71, 'way': 72, 'max': 73, 'two': 74, 'god': 75, 'first': 76, 'make': 77, 'much': 78, 'many': 79, 'those': 80, 'most': 81, 'ca': 82, 've': 83, 'say': 84, 'such': 85, 'here': 86, 'right': 87, 'system': 88, 'did': 89, 'where': 90, 'our': 91, 'want': 92, 'anyone': 93, 'go': 94, 'used': 95, 'after': 96, 'said': 97, 'being': 98, 'over': 99, 'its': 100, 'same': 101, 'cs': 102, 'need': 103, 'work': 104, 'problem': 105, 'too': 106, 'something': 107, 'really': 108, 'please': 109, 'him': 110, 'since': 111, 'believe': 112, 'back': 113, 'off': 114, 'windows': 115, 'still': 116, 'going': 117, 'mail': 118, 'find': 119, 'help': 120, 'before': 121, 'take': 122, 'point': 123, 'year': 124, 'using': 125, 'll': 126, 'question': 127, 'file': 128, 'last': 129, 'years': 130, 'might': 131, 'never': 132, 'thanks': 133, 'both': 134, 'while': 135, 'better': 136, 'read': 137, 'things': 138, 'must': 139, 'own': 140, 'etc': 141, 'number': 142, 'another': 143, 'without': 144, 'sure': 145, 'world': 146, 'david': 147, 'made': 148, 'someone': 149, 'state': 150, 'down': 151, 'through': 152, 'let': 153, 'doesn': 154, 'drive': 155, 'bit': 156, 'got': 157, 'between': 158, 'data': 159, 'space': 160, 'long': 161, 'program': 162, 'thing': 163, 'under': 164, 'look': 165, 'part': 166, 'available': 167, 'few': 168, 'software': 169, 'day': 170, 'power': 171, 'around': 172, 'come': 173, 'little': 174, 'case': 175, 'fact': 176, 'each': 177, 'anything': 178, 'didn': 179, 'however': 180, 'again': 181, 'give': 182, 'against': 183, 'news': 184, 'key': 185, 'best': 186, 'law': 187, 'game': 188, 'every': 189, 'she': 190, 'probably': 191, 'seems': 192, 'uk': 193, 'john': 194, 'different': 195, 'least': 196, 'true': 197, 'tell': 198, 'dos': 199, 'enough': 200, 'put': 201, 'set': 202, 'car': 203, 'run': 204, 'try': 205, 'computer': 206, 'course': 207, 'lot': 208, 'name': 209, 'actually': 210, 'her': 211, 'list': 212, 'ac': 213, 'great': 214, 'org': 215, 'says': 216, 'real': 217, 'high': 218, 'hard': 219, 'line': 220, 'far': 221, 'either': 222, 'post': 223, 'though': 224, 'life': 225, 'group': 226, 'old': 227, 'called': 228, 'support': 229, 'second': 230, 'nothing': 231, 'man': 232, 'possible': 233, 'free': 234, 'else': 235, 'wrong': 236, 'end': 237, 'rather': 238, 'gov': 239, 'net': 240, 'image': 241, 'public': 242, 'mean': 243, 'card': 244, 'call': 245, 'reason': 246, 'team': 247, 'jesus': 248, 'yes': 249, 'problems': 250, 'cc': 251, 'looking': 252, 'files': 253, 'mr': 254, 'keep': 255, 'version': 256, 'next': 257, 'person': 258, 'based': 259, 'found': 260, 'above': 261, 'mark': 262, 'maybe': 263, 'done': 264, 'non': 265, 'email': 266, 'seen': 267, 'others': 268, 'able': 269, 'sun': 270, 'order': 271, 'having': 272, 'yet': 273, 'always': 274, 'gun': 275, 'place': 276, 'general': 277, 'three': 278, 'isn': 279, 'send': 280, 'graphics': 281, 'ever': 282, 'bill': 283, 'thought': 284, 'bad': 285, 'chip': 286, 'example': 287, 'pc': 288, 'quite': 289, 'heard': 290, 'internet': 291, 'doing': 292, 'info': 293, 'following': 294, 'less': 295, 'once': 296, 'nasa': 297, 'mac': 298, 'wrote': 299, 'trying': 300, 'control': 301, 'de': 302, 'left': 303, 'windo ...

# %% [markdown]
# ### Loading the predefined word2vec file

# %% [markdown]
# we aim to predict the next word given the context in which the word appears. (For example, given the last 𝑛 words, predict the next word). A very smart way to do this is by using a feature representation called "Word2Vec" with transforms each word into 300-dimensional vectors.
# Link to pretrained 300 dimensional word2vec: https://drive.google.com/uc?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM&export=download
#
#
# Converting each document into average of the word2vec vectors of all valid words in document.

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('AIML_DS_GOOGLENEWS-VECTORS-NEGATIVE-300_STD.bin', binary=True, limit=500000)

# %% [markdown]
# ### Function for word2vec

# %%
word2vec_vector_size = 300

'''
 This method converts documents to word vectors. It first checks if the word is valid according to our initial frequency
 threshold. Next, if it is, we add the precomputed word vectors together. If the word is valid, but we do not have a valid
 vector to represent the word, we add a random gaussian noise instead. Since we do not want to induce new noise each time,
 we store the same noise vector for training and test time in substitute_word_vecs variable.
'''
def convert_to_w2v(dataset, number_of_documents, substitute_word_vecs={}):
    d = {}
    labels = np.zeros((number_of_documents, 1))
    w2v_rep = np.zeros((number_of_documents, word2vec_vector_size))

    # Iterate over the dataset and split into words
    i = 0
    for label, class_name in enumerate(dataset):
        for f in dataset[class_name]:
            text = ' '.join(f).split(' ')
            valid_count = 1
            for word in text:

                # Check if word is valid or not according to original dataset pruning
                if word in valid_words:
                    try:
                        w2v_rep[i] += model[word]
                        # YOUR CODE HERE. For each 'word' variable above, get a word2vec representation using the model
                        #..loaded above within 'model'
                        d[word] = model[word]
                    except:
                        '''The word isn't in our pretrained word-vectors, hence we add a random gaussian noise
                         to account for this. We store the random vector we assigned to the word, and reuse
                         the same vector during test time to ensure consistency.'''

                        if word not in substitute_word_vecs.keys():
                            substitute_word_vecs[word] = np.random.normal(-0.25, 0.25, word2vec_vector_size)

                        w2v_rep[i] += substitute_word_vecs[word]

                    valid_count += 1

            # Average
            w2v_rep[i] = w2v_rep[i] / valid_count

            # Save label
            labels[i] = label

            i += 1

    return d, w2v_rep, labels, substitute_word_vecs

# %% [markdown]
# ### Convert the train and test datasets into their word2vec representations

# %%
d_train,train_w2v_set, train_w2v_labels, substitute_word_vecs = convert_to_w2v(train_set, n_train)
d_test,test_w2v_set, test_w2v_labels,_ = convert_to_w2v(test_set, n_test, substitute_word_vecs)

# %%
print(len(d_train))
print(len(train_w2v_set[0]))
# Out:
# 3687
# 300

# %% [markdown]
# ### Defining the Model
#
#
# Let us create an autoencoder architecture. Typically an autoencoder is made up of two components, the encoder network and the decoder network. Encoding network is made up of four layers where we are trying to compressing the data into 2 features which can be easily visualized in the plot.  Decoding network is made up of four layers.
#
# The sentences in the documents as word2vec representation are fed into the encoder network, transformed into a semantic vector of fixed size, and then unfolded back into an ordered sentences in document.

# %%
class autoencoder(nn.Module):
    def __init__(self):
        super(autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(300,100),
            nn.ReLU(),
            nn.Linear(100,30),
            # YOUR CODE HERE: Define a Linear Layer with input size 100 and output size 30
            nn.ReLU(),
            nn.Linear(30,30),
            # YOUR CODE HERE: Define a Linear Layer with input size 30 and output size 30
            nn.ReLU(),
            nn.Linear(30,2)
            )
            # YOUR CODE HERE: Define a Linear Layer with input size 30 and output size 2

        self.decoder = nn.Sequential(

            # YOUR CODE HERE: Define a Linear Layer with input size 2 and output size 30
            nn.Linear(2,30),
            nn.ReLU(),
            # YOUR CODE HERE: Define a Linear Layer with input size 30 and output size 30
            nn.Linear(30,30),
            nn.ReLU(),
            nn.Linear(30,100),
            # YOUR CODE HERE: Define a Linear Layer with input size 30 and output size 100
            nn.ReLU(),
            nn.Linear(100,300)
            # YOUR CODE HERE: Define a Linear Layer with input size 100 and output size 300
        )
    def forward(self, x):
        y = self.encoder(x)
        z = self.decoder(y)
        return y,z

# %% [markdown]
# ### Calling the instances of the network

# %%
model = autoencoder()

# YOUR CODE HERE: Create an object for 'autoencoder' class defined above
model
# Out:
# autoencoder(
#   (encoder): Sequential(
#     (0): Linear(in_features=300, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=30, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=30, out_features=30, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=30, out_features=2, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=2, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=30, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=30, out_features=100, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=100, out_features=300, bias=True)
#   )
# )

# %% [markdown]
# ### Defining the loss function and optimizer

# %%
criterion = nn.MSELoss()
# YOUR CODE HERE: Define the mean square error loss function
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

# %% [markdown]
# ### Training the Model
#
# 1. Pass the data through the model.
# 2. Calculate the loss by comparing the reconstructed image with the original image
# 3. Train the model to minimize the reconstruction error which measures the diference between the original image and the consequent reconstructed image.

# %%
EPOCH = 10
for epoch in range(EPOCH):
    for i, (word, w2v) in enumerate(d_train.items()):
        b_x = torch.FloatTensor(np.array(w2v))     # Converting an array to a tensor


        # Passing the data to the model (Forward Pass)
        encoded, decoded = model(b_x)
         # YOUR CODE HERE : Call 'model' defined above by passing 'b_x' as arguments.

    #     # Calculating mean square error loss
        loss = criterion(decoded, b_x)

    #     # Zero the parameter gradients
        optimizer.zero_grad()

    #     # YOUR CODE HERE : Perform backward pass
        loss.backward()

    #     # optimizer.step() updates the weights accordingly
        optimizer.step()

    print("Loss:",float(loss))
# Out:
# Loss: 0.06744152307510376
# Loss: 0.06660252809524536
# Loss: 0.06592296063899994
# Loss: 0.06534478813409805
# Loss: 0.06484393775463104
# Loss: 0.06440668553113937
# Loss: 0.06402260810136795
# Loss: 0.06368160992860794
# Loss: 0.0633719190955162
# Loss: 0.06309742480516434

# %% [markdown]
# We will convert training dataset first into a torch tensor, and form a differentiable Variable.

# %%
value = torch.Tensor(np.array(train_w2v_set))
# YOUR CODE Here : Convert an array 'train_w2v_set' defined above to a tensor

# Passing the data to the model (Forward Pass)
encoder_values, decoder_values = model(value)

# %%
# Converting pytorch variable into numpy array
encode = encoder_values.data.numpy()
decode = decoder_values.data.numpy()

# %%
print(encode.shape, decode.shape)
# Out:
# (17878, 2) (17878, 300)

# %%
# Storing all the words in words list
words =[]
for key in substitute_word_vecs:
    words.append(key)

# %% [markdown]
# ### Visualization of encoded data
#
# To visualize the higher dimensional data in 2D space, we can use autoencoders.

# %%
# YOUR CODE HERE : To plot the encode data and annotate each point in the plot.

plt.figure(figsize=(10,6))
plt.scatter(encode[:50,0],encode[:50,1])
for i in range(len(words[:50]) - 1):
    plt.annotate(words[i], xy = (encode[i][0],encode[i][1]))
plt.show()

# %% [markdown]
# ### Please answer the questions below to complete the experiment:

# %%
#@title State True or False: In this experiment, Reconstruction error is different from loss function (MSE) which calculates the difference between output vector and input vector. { run: "auto", form-width: "500px", display-mode: "form" }
Answer = "FALSE" #@param ["","TRUE", "FALSE"]

# %%
#@title How was the experiment? { run: "auto", form-width: "500px", display-mode: "form" }
Complexity = "Good and Challenging for me" #@param ["","Too Simple, I am wasting time", "Good, But Not Challenging for me", "Good and Challenging for me", "Was Tough, but I did it", "Too Difficult for me"]

# %%
#@title If it was too easy, what more would you have liked to be added? If it was very difficult, what would you have liked to have been removed? { run: "auto", display-mode: "form" }
Additional = "na" #@param {type:"string"}

# %%
#@title Can you identify the concepts from the lecture which this experiment covered? { run: "auto", vertical-output: true, display-mode: "form" }
Concepts = "Yes" #@param ["","Yes", "No"]

# %%
#@title  Experiment walkthrough video? { run: "auto", vertical-output: true, display-mode: "form" }
Walkthrough = "Somewhat Useful" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title  Text and image description/explanation and code comments within the experiment: { run: "auto", vertical-output: true, display-mode: "form" }
Comments = "Somewhat Useful" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title Mentor Support: { run: "auto", vertical-output: true, display-mode: "form" }
Mentor_support = "Didn't use" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title Run this cell to submit your notebook for grading { vertical-output: true }
try:
  if submission_id:
      return_id = submit_notebook()
      if return_id : submission_id = return_id
  else:
      print("Please complete the setup first.")
except NameError:
  print ("Please complete the setup first.")
# Out:
# Your submission is successful.
# Ref Id: 7780
# Date of submission:  28 Sep 2024
# Time of submission:  17:09:53
# View your submissions: https://aiml-iiith.talentsprint.com/notebook_submissions
